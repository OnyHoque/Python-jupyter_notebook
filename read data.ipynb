# %%
data = []
f = open('inputTAM.txt')

data.extend(f.read().split('\n'))

# %%
data
# Out:
# ['0 city FOLO',
#  '0 flu local aede malaria worry shop lot use cont',
#  '0 case',
#  '0 dengue menace',
#  '0 dictionary noun process kill mosquitos hide room avoid fever',
#  '0 unit blood need patient',
#  '0 need blood need patient',
#  '0 stage come person infect denguelikefever',
#  '0 stage come person infect',
#  '0 stage come person infecte',
#  '0 return official Bangladesh news hour',
#  '0 base prevalence malaria dengue febrile patient bangladesh',
#  '0 factory produce mosquito net combat malaria dengue Bangladesh socialbusiness',
#  '0 variability dengue transmission',
#  '0 hospital kajang Bangladesh worker top most admission dengue malaria poor work place',
#  '0 get old mosquito net notice sudden outbreak want get dengue',
#  '0 berkemungkinan nyamuk aedes hujan langit besar kita Akan dijangkito denggi',
#  '0 open sewerage morning wake fear dengue polio typhoid cholera',
#  '0 emergency bag need Dengue',
# ...
