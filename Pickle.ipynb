# %%
import pickle
import random

# %%
Start = 1000
Stop = 100000
limit = 1000

data = [random.randint(Start, Stop) for iter in range(limit)]

# %%
data
# Out:
# [2304,
#  33326,
#  68304,
#  39280,
#  31845,
#  74373,
#  29356,
#  63474,
#  90352,
#  29512,
#  80104,
#  95198,
#  85715,
#  10881,
#  54056,
#  16275,
#  37785,
#  84036,
#  97876,
#  17786,
#  45899,
#  2646,
#  17886,
#  56519,
#  63133,
#  19516,
#  21200,
#  32967,
#  66359,
#  55351,
#  43107,
#  98295,
#  47213,
#  46431,
#  7532,
#  83244,
#  66466,
#  41270,
#  50064,
#  3730,
#  10465,
#  22729,
#  46679,
#  68080,
#  81395,
#  65285,
#  10216,
#  93674,
#  90766,
#  90637,
#  20068,
#  53873,
#  12612,
#  86275,
#  70375,
#  74299,
#  7042,
#  90555,
#  83592,
#  99766,
#  81341,
#  46044,
#  57115,
#  54121,
#  9714,
#  45398,
#  92128,
#  12082,
#  24531,
#  37850,
#  80088,
#  29064,
#  57408,
#  70308,
#  91407,
#  86153,
#  26096,
#  96746,
#  78694,
#  34119,
#  81247,
#  23102,
#  24338,
#  41338,
#  90894,
#  23452,
#  14585,
#  26130,
#  60551,
#  6267,
#  59441,
#  19994,
#  66267,
#  48288,
#  94965,
#  21560,
#  87765,
#  96385,
#  68985,
#  29788,
# ...

# %%
pickle_file = open("data.pk","wb")
pickle.dump(data, pickle_file)
pickle_file.close()

# %%
pickle_file = open("data.pk","rb")
data_load = pickle.load(pickle_file)

# %%
data_load
# Out:
# [2304,
#  33326,
#  68304,
#  39280,
#  31845,
#  74373,
#  29356,
#  63474,
#  90352,
#  29512,
#  80104,
#  95198,
#  85715,
#  10881,
#  54056,
#  16275,
#  37785,
#  84036,
#  97876,
#  17786,
#  45899,
#  2646,
#  17886,
#  56519,
#  63133,
#  19516,
#  21200,
#  32967,
#  66359,
#  55351,
#  43107,
#  98295,
#  47213,
#  46431,
#  7532,
#  83244,
#  66466,
#  41270,
#  50064,
#  3730,
#  10465,
#  22729,
#  46679,
#  68080,
#  81395,
#  65285,
#  10216,
#  93674,
#  90766,
#  90637,
#  20068,
#  53873,
#  12612,
#  86275,
#  70375,
#  74299,
#  7042,
#  90555,
#  83592,
#  99766,
#  81341,
#  46044,
#  57115,
#  54121,
#  9714,
#  45398,
#  92128,
#  12082,
#  24531,
#  37850,
#  80088,
#  29064,
#  57408,
#  70308,
#  91407,
#  86153,
#  26096,
#  96746,
#  78694,
#  34119,
#  81247,
#  23102,
#  24338,
#  41338,
#  90894,
#  23452,
#  14585,
#  26130,
#  60551,
#  6267,
#  59441,
#  19994,
#  66267,
#  48288,
#  94965,
#  21560,
#  87765,
#  96385,
#  68985,
#  29788,
# ...
